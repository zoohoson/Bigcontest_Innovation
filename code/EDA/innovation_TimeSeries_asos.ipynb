# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.float_format', '{:.2f}'.format) # 항상 float 형식으로

# %% [markdown]
# * 아래 코드는 주피터에서는 실행안되고 py로만 가능

# %%
# import pandas as pd

# df_asos_no1 = pd.read_csv('./data/innovation/asos/노원구/V10O1610610.csv')
# df_asos_no2 = pd.read_csv('./data/innovation/asos/노원구/V10O1610376.csv')
# df_asos_no3 = pd.read_csv('./data/innovation/asos/노원구/V10O1610293.csv')
# df_asos_no4 = pd.read_csv('./data/innovation/asos/노원구/V10O1610356.csv')
# df_asos_no5 = pd.read_csv('./data/innovation/asos/노원구/V10O1610616.csv')
# df_asos_no6 = pd.read_csv('./data/innovation/asos/노원구/V10O1610200.csv')
# df_asos_no7 = pd.read_csv('./data/innovation/asos/노원구/V10O1610643.csv')
# df_asos_no8 = pd.read_csv('./data/innovation/asos/노원구/V10O1610642.csv')
# df_asos_no9 = pd.read_csv('./data/innovation/asos/노원구/V10O1610297.csv')
# df_asos_no10 = pd.read_csv('./data/innovation/asos/노원구/V10O1610312.csv')
# df_asos_no11 = pd.read_csv('./data/innovation/asos/노원구/V10O1610102.csv')
# df_asos_no12 = pd.read_csv('./data/innovation/asos/노원구/V10O1610351.csv')
# df_asos_no13 = pd.read_csv('./data/innovation/asos/노원구/V10O1610629.csv')
# df_asos_no14 = pd.read_csv('./data/innovation/asos/노원구/V10O1610630.csv')
# df_asos_no15 = pd.read_csv('./data/innovation/asos/노원구/V10O1611104.csv')
# df_asos_no16 = pd.read_csv('./data/innovation/asos/노원구/V10O1611097.csv')
# df_asos_no17 = pd.read_csv('./data/innovation/asos/노원구/V10O1611100.csv')
# df_asos_no18 = pd.read_csv('./data/innovation/asos/노원구/V10O1612126.csv')
# df_asos_no19 = pd.read_csv('./data/innovation/asos/노원구/V10O1611102.csv')
# df_asos_no20 = pd.read_csv('./data/innovation/asos/노원구/V10O1611652.csv')
# df_asos_no21 = pd.read_csv('./data/innovation/asos/노원구/V10O1611150.csv')
# df_asos_no22 = pd.read_csv('./data/innovation/asos/노원구/V10O1611229.csv')


# def change_cols(data):
#     data['DATE'] = [str(data.tm[i])[:8] for i in range(len(data))]

#     drop_cols = ['serial', 'flag', 'co2', 'vocs', 'noise', 'temp', 'humi', 'Unnamed: 10', 'tm']
#     data.drop(drop_cols, axis=1, inplace=True)

#     data = data.groupby('DATE').mean()
#     data = data.reset_index()

#     print(data.shape)
#     return data


# df_asos_no1 = change_cols(df_asos_no1)
# df_asos_no2 = change_cols(df_asos_no2)
# df_asos_no3 = change_cols(df_asos_no3)
# df_asos_no4 = change_cols(df_asos_no4)
# df_asos_no5 = change_cols(df_asos_no5)
# df_asos_no6 = change_cols(df_asos_no6)
# df_asos_no7 = change_cols(df_asos_no7)
# df_asos_no8 = change_cols(df_asos_no8)
# df_asos_no9 = change_cols(df_asos_no9)
# df_asos_no10 = change_cols(df_asos_no10)
# df_asos_no11 = change_cols(df_asos_no11)
# df_asos_no12 = change_cols(df_asos_no12)
# df_asos_no13 = change_cols(df_asos_no13)
# df_asos_no14 = change_cols(df_asos_no14)
# df_asos_no15 = change_cols(df_asos_no15)
# df_asos_no16 = change_cols(df_asos_no16)
# df_asos_no17 = change_cols(df_asos_no17)
# df_asos_no18 = change_cols(df_asos_no18)
# df_asos_no19 = change_cols(df_asos_no19)
# df_asos_no20 = change_cols(df_asos_no20)
# df_asos_no21 = change_cols(df_asos_no21)
# df_asos_no22 = change_cols(df_asos_no22)



# df_asos_jong1 = pd.read_csv('./data/innovation/asos/종로구/V10O1610252.csv')
# df_asos_jong2 = pd.read_csv('./data/innovation/asos/종로구/V10O1610546.csv')
# df_asos_jong3 = pd.read_csv('./data/innovation/asos/종로구/V10O1610540.csv')
# df_asos_jong4 = pd.read_csv('./data/innovation/asos/종로구/V10O1610542.csv')
# df_asos_jong5 = pd.read_csv('./data/innovation/asos/종로구/V10O1610543.csv')
# df_asos_jong6 = pd.read_csv('./data/innovation/asos/종로구/V10O1610544.csv')
# df_asos_jong7 = pd.read_csv('./data/innovation/asos/종로구/V10O1610545.csv')
# df_asos_jong8 = pd.read_csv('./data/innovation/asos/종로구/V10O1610567.csv')
# df_asos_jong9 = pd.read_csv('./data/innovation/asos/종로구/V01o1610468.csv')
# df_asos_jong10 = pd.read_csv('./data/innovation/asos/종로구/V10O1611289.csv')
# df_asos_jong11 = pd.read_csv('./data/innovation/asos/종로구/V10O1611172.csv')
# df_asos_jong12 = pd.read_csv('./data/innovation/asos/종로구/V10O1611634.csv')
# df_asos_jong13 = pd.read_csv('./data/innovation/asos/종로구/V10O1611887.csv')
# df_asos_jong14 = pd.read_csv('./data/innovation/asos/종로구/V10O1611639.csv')
# df_asos_jong15 = pd.read_csv('./data/innovation/asos/종로구/V10O1611658.csv')
# df_asos_jong16 = pd.read_csv('./data/innovation/asos/종로구/V10O1612113.csv')
# df_asos_jong17 = pd.read_csv('./data/innovation/asos/종로구/V10O1611151.csv')
# df_asos_jong18 = pd.read_csv('./data/innovation/asos/종로구/V10O1611145.csv')
# df_asos_jong19 = pd.read_csv('./data/innovation/asos/종로구/V10O1611623.csv')
# df_asos_jong20 = pd.read_csv('./data/innovation/asos/종로구/V10O1611750.csv')
# df_asos_jong21 = pd.read_csv('./data/innovation/asos/종로구/V10O1611170.csv')
# df_asos_jong22 = pd.read_csv('./data/innovation/asos/종로구/V10O1611684.csv')
# df_asos_jong23 = pd.read_csv('./data/innovation/asos/종로구/V10O1611220.csv')
# df_asos_jong24 = pd.read_csv('./data/innovation/asos/종로구/V10O1612106.csv')
# df_asos_jong25 = pd.read_csv('./data/innovation/asos/종로구/V10O1611251.csv')
# df_asos_jong26 = pd.read_csv('./data/innovation/asos/종로구/V10O1611173.csv')
# df_asos_jong27 = pd.read_csv('./data/innovation/asos/종로구/V10O1611258.csv')
# df_asos_jong28 = pd.read_csv('./data/innovation/asos/종로구/V10O1611255.csv')
# df_asos_jong29 = pd.read_csv('./data/innovation/asos/종로구/V10O1611698.csv')
# df_asos_jong30 = pd.read_csv('./data/innovation/asos/종로구/V10O1611722.csv')
# df_asos_jong31 = pd.read_csv('./data/innovation/asos/종로구/V10O1611645.csv')

# df_asos_jong1 = change_cols(df_asos_jong1)
# df_asos_jong2 = change_cols(df_asos_jong2)
# df_asos_jong3 = change_cols(df_asos_jong3)
# df_asos_jong4 = change_cols(df_asos_jong4)
# df_asos_jong5 = change_cols(df_asos_jong5)
# df_asos_jong6 = change_cols(df_asos_jong6)
# df_asos_jong7 = change_cols(df_asos_jong7)
# df_asos_jong8 = change_cols(df_asos_jong8)
# df_asos_jong9 = change_cols(df_asos_jong9)
# df_asos_jong10 = change_cols(df_asos_jong10)
# df_asos_jong11 = change_cols(df_asos_jong11)
# df_asos_jong12 = change_cols(df_asos_jong12)
# df_asos_jong13 = change_cols(df_asos_jong13)
# df_asos_jong14 = change_cols(df_asos_jong14)
# df_asos_jong15 = change_cols(df_asos_jong15)
# df_asos_jong16 = change_cols(df_asos_jong16)
# df_asos_jong17 = change_cols(df_asos_jong17)
# df_asos_jong18 = change_cols(df_asos_jong18)
# df_asos_jong19 = change_cols(df_asos_jong19)
# df_asos_jong20 = change_cols(df_asos_jong20)
# df_asos_jong21 = change_cols(df_asos_jong21)
# df_asos_jong22 = change_cols(df_asos_jong22)
# df_asos_jong23 = change_cols(df_asos_jong23)
# df_asos_jong24 = change_cols(df_asos_jong24)
# df_asos_jong25 = change_cols(df_asos_jong25)
# df_asos_jong26 = change_cols(df_asos_jong26)
# df_asos_jong27 = change_cols(df_asos_jong27)
# df_asos_jong28 = change_cols(df_asos_jong28)
# df_asos_jong29 = change_cols(df_asos_jong29)
# df_asos_jong30 = change_cols(df_asos_jong30)
# df_asos_jong31 = change_cols(df_asos_jong31)

# %%
df_asos_no15 = pd.read_csv('./data/innovation/asos/노원구/V10O1611104.csv')  # 상계 6, 7동
df_asos_jong13 = pd.read_csv('./data/innovation/asos/종로구/V10O1611887.csv')  # 명동

# %%
df_asos_no15.head()
# Out:
#              tm       serial  flag  pm10   co2  vocs  noise  temp  humi  pm25  \
# 0  201804010000  V10O1611104     1    55 -9999 -9999     50 14.20    51 33.00
# 1  201804010001  V10O1611104     1    53 -9999 -9999     51 14.20    51 32.00
# 2  201804010002  V10O1611104     1    47 -9999 -9999     50 14.20    51 28.00
# 3  201804010003  V10O1611104     1    60 -9999 -9999     50 14.10    51 36.00
# 4  201804010004  V10O1611104     1    57 -9999 -9999     50 14.10    51 34.00
#
#    Unnamed: 10
# 0          nan
# 1          nan
# 2          nan
# 3          nan
# 4          nan

# %% [markdown]
# # pk확인

# %%
df_asos_no15.shape, df_asos_jong13.shape
# Out:
# ((525600, 11), (525600, 11))

# %%
len(df_asos_no15.groupby(['tm']).count())
# Out:
# 525600

# %%
df_rain = pd.read_csv('./data/innovation/asos/day_rain.csv', encoding='cp949')

# %%
df_rain.head()
# Out:
#            날짜   지점  강수량(mm)
# 0  2018-04-01  108      nan
# 1  2018-04-02  108      nan
# 2  2018-04-03  108     0.10
# 3  2018-04-04  108    18.50
# 4  2018-04-05  108    10.50

# %%
df_news = pd.read_csv('./data/innovation/df_news.csv')

# %%
df_news.head()
# Out:
#        DATE  CONTENT
# 0  20180401      515
# 1  20180402      888
# 2  20180403      856
# 3  20180404      893
# 4  20180405      864

# %%
df_rain.drop(['날짜', '지점'], axis=1, inplace=True)

# %%
df_rain.isnull().sum()
# Out:
# 강수량(mm)    240
# dtype: int64

# %%
df_rain.shape
# Out:
# (365, 1)

# %%
df_rain = df_rain.fillna(0)

# %%
df_asos_no15 = df_asos_no15.replace(-999, df_asos_no15.replace([-999], [None]))
df_asos_no15 = df_asos_no15.replace(-9999, df_asos_no15.replace([-9999], [None]))

# %%
df_asos_no15.isnull().sum()
# Out:
# tm                  0
# serial              0
# flag              200
# pm10              614
# co2            525600
# vocs           525600
# noise             333
# temp              333
# humi              333
# pm25              614
# Unnamed: 10    525600
# dtype: int64

# %%
df_asos_jong13 = df_asos_jong13.replace(-999, df_asos_jong13.replace([-999], [None]))
df_asos_jong13 = df_asos_jong13.replace(-9999, df_asos_jong13.replace([-9999], [None]))

# %%
df_asos_jong13.isnull().sum()
# Out:
# tm                  0
# serial              0
# flag              407
# pm10              702
# co2            525600
# vocs           525600
# noise             444
# temp              444
# humi              444
# pm25              702
# Unnamed: 10    525600
# dtype: int64

# %% [markdown]
# * 노원구 데이터 전처리

# %%
df_asos_no15['DATE'] = [str(df_asos_no15.tm[i])[:8] for i in range(len(df_asos_no15))]

# %%
plt.figure(figsize=(18,6))
plt.plot(df_asos_no15.index, df_asos_no15[['pm10']])

# %%
outlier_idx = np.where(df_asos_no15.pm10>=250)[0]

# %%
drop_cols = ['serial', 'flag', 'co2', 'vocs', 'noise', 'Unnamed: 10', 'tm']
df_asos_no15.drop(drop_cols, axis=1, inplace=True)

# %%
df_asos_no15 = df_asos_no15.groupby('DATE').mean()
df_asos_no15 = df_asos_no15.reset_index()

# %%
df_asos_no15['GU_NM']=['노원구']*len(df_asos_no15)

# %% [markdown]
# * 종로구 데이터 전처리

# %%
df_asos_jong13['DATE'] = [str(df_asos_jong13.tm[i])[:8] for i in range(len(df_asos_jong13))]

# %%
drop_cols = ['serial', 'flag', 'co2', 'vocs', 'noise', 'Unnamed: 10', 'tm']
df_asos_jong13.drop(drop_cols, axis=1, inplace=True)

# %%
df_asos_jong13 = df_asos_jong13.groupby('DATE').mean()
df_asos_jong13 = df_asos_jong13.reset_index()

# %%
df_asos_jong13['GU_NM']=['종로구']*len(df_asos_jong13)

# %%
df_asos = pd.concat([df_asos_no15, df_asos_jong13]).groupby(['DATE', 'GU_NM']).sum().reset_index()

# %%
df_asos.head()
# Out:
#        DATE GU_NM       pm10       temp       pm25
# 0  20180401   노원구  68.328472   9.623264  35.256944
# 1  20180401   종로구  84.070139  16.692569  43.877083
# 2  20180402   노원구  72.005556  12.671250  29.909028
# 3  20180402   종로구  72.274306  19.561181  30.051389
# 4  20180403   노원구  72.838194  12.234375  24.295833

# %% [markdown]
# # Load df_news

# %%
df_news = pd.read_csv('./data/innovation/df_news.csv')

# %% [markdown]
# # 1차 Merge. 일별 데이터

# %%
dateidx = pd.date_range('2018-04-01', '2019-03-31')
df_asos = df_asos.groupby('DATE').mean()
df_asos.index = dateidx
df_news.index = dateidx

# %%
df_news.drop('DATE', axis=1, inplace=True)

# %%
df_total = df_asos.merge(df_news, on=df_news.index).set_index('key_0')

# %%
df_total.to_csv('./data/innovation/df_asos.csv', index=False)

# %% [markdown]
# # 2차 Merge. 일별 노원구데이터

# %%
df_nowon = pd.read_csv('./data/innovation/asos/nowon.csv', header=None)

# %%
df_asos_no15.shape
# Out:
# (525600, 11)

# %%
df_nowon.columns = ['time', 'noise', 'temp', 'humi', 'pm10', 'pm25']

# %%
df_nowon['time'] = df_asos_no15.tm

# %%
plt.figure(figsize=(18,6))
plt.plot(df_nowon.time, df_nowon[['pm10', 'pm25', 'temp']])

# %%
df_nowon['DATE'] = [str(df_nowon.time[i])[:8] for i in range(len(df_nowon))]

# %%
df_nowon = df_nowon.groupby('DATE').mean()

# %%
df_nowon.drop('time', axis=1, inplace=True)

# %%
fig, ax0 = plt.subplots(figsize=(18, 6))
ax1 = ax0.twinx()
ax0.plot(df_nowon.index, df_nowon[['pm10', 'pm25']])
ax1.plot(df_nowon.index, df_nowon[['temp']], 'g-')
fig.legend(['pm10', 'pm25', 'temp'])

# %%
df_total = df_nowon.merge(df_news, on=df_news.index).set_index('key_0')

# %%
df_total = df_total.merge(df_rain, on=df_total.index).set_index('key_0')

# %%
df_total.index = pd.date_range('2018-04-01', '2019-03-31')

# %%
outlier_idx = np.where(df_total.pm10>=300)[0]
outlier_idx = df_total.iloc[outlier_idx].index
# df_total.loc[outlier_idx]

# %%
df_total.loc[outlier_idx, "pm10"]=201  # airkorea
df_total.loc[outlier_idx, "pm25"]=143  # airkorea 데이터참고 이상치처리

# %%
fig, ax0 = plt.subplots(figsize=(18, 6))
ax1 = ax0.twinx()
ax0.plot(df_total.index, df_total[['pm10', 'pm25']])
ax1.plot(df_total.index, df_total[['temp']], 'g-')
fig.legend(['pm10', 'pm25', 'temp'])

# %%
df_total.to_csv('./data/innovation/create/df_asos_nowon.csv', index=False)
