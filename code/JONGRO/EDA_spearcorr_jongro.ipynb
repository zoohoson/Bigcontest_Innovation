# %% [markdown]
# # Spearcorr를 이용하여 실제 상관관계 파악

# %%
import pandas as pd # 데이터 프레임 처리
import numpy as np # 벡터 계산
import matplotlib.pyplot as plt # 데이터 시각화
import seaborn as sns
# 사이킷런 패키지 활용
from sklearn.linear_model import LinearRegression
from scipy.stats import spearmanr

# %%
total_20 = pd.read_csv('/root/Big_Contest/EDA/Data/Age/df_age20_jongro.csv') # 20대 노원구 데이터
total_30 = pd.read_csv('/root/Big_Contest/EDA/Data/Age/df_age30_jongro.csv') # 30대 노원구 데이터
total_40 = pd.read_csv('/root/Big_Contest/EDA/Data/Age/df_age40_jongro.csv') # 40대 노원구 데이터
total_50 = pd.read_csv('/root/Big_Contest/EDA/Data/Age/df_age50_jongro.csv') # 50대 노원구 데이터

# %%
# 시계열 데이터로 만들기 위해서 기존의 인덱스를 2018.04.01 ~ 2019.03.31로 변경
dateIdx = pd.date_range('2018-04-01', '2019-03-31')

total_20.index = dateIdx
total_30.index = dateIdx
total_40.index = dateIdx
total_50.index = dateIdx

# %%
total_20.head()
# Out:
#             age20accum  age20leisure goods  age20leisure busi  age20culture  \
# 2018-04-01       685.0               318.0             3730.0        1977.0
# 2018-04-02       212.0               188.0             2626.0         596.0
# 2018-04-03       257.0               192.0             2831.0         782.0
# 2018-04-04       205.0               202.0             2716.0         772.0
# 2018-04-05       273.0               184.0             2898.0        1001.0
#
#             age20furniture  age20electronic  age20kitchen  age20fuel  \
# 2018-04-01             0.0              0.0           0.0       59.0
# 2018-04-02             0.0              0.0           0.0       55.0
# 2018-04-03            12.0              0.0           0.0       64.0
# 2018-04-04             8.0              0.0          17.0        0.0
# 2018-04-05             0.0              0.0          21.0       47.0
#
#             age20optic  age20Appliances  ...  LCLS_50_P  LCLS_60_P  LCLS_70_P  \
# 2018-04-01        99.0             17.0  ...      68124      10029      15065
# 2018-04-02        91.0              0.0  ...      66428       9316      15306
# 2018-04-03       113.0             51.0  ...      66698       7793      13618
# 2018-04-04       106.0             56.0  ...      83667       9649      19985
# 2018-04-05        60.0             21.0  ...     108727       9057      13849
#
#             LCLS_80_P       pm10       pm25       humi       temp  CONTENT  \
# 2018-04-01       4995  84.070139  43.877083  61.370139  16.692569      515
# 2018-04-02       3638  72.274306  30.051389  58.825694  19.561181      888
# 2018-04-03       2648  66.162500  19.478472  63.531944  19.282292      856
# 2018-04-04       3078  18.021097  10.726442  62.014583  14.202361      893
# 2018-04-05       3796  11.831711   8.579972  79.125000   8.963056      864
#
#             rain
# 2018-04-01   0.0
# 2018-04-02   0.0
# 2018-04-03   0.1
# 2018-04-04  18.5
# 2018-04-05  10.5
#
# [5 rows x 38 columns]

# %%
corrs_CONTENT_20 = []
corrs_pm10_20 = []
corrs_pm25_20 = []
corrs_temp_20 = []
corrs_humi_20 = []
corrs_rain_20 = []

for c in list(total_20.columns)[:-6] :
    corrs_CONTENT_20.append(spearmanr(total_20[["CONTENT"]], total_20[[c]])[0])
    corrs_pm10_20.append(spearmanr(total_20[["pm10"]], total_20[[c]])[0])
    corrs_pm25_20.append(spearmanr(total_20[["pm25"]], total_20[[c]])[0])
    corrs_temp_20.append(spearmanr(total_20[["temp"]], total_20[[c]])[0])
    corrs_humi_20.append(spearmanr(total_20[["humi"]], total_20[[c]])[0])
    corrs_rain_20.append(spearmanr(total_20[["rain"]], total_20[[c]])[0])
    
corrs_dict_20 = {"CONTENT":corrs_CONTENT_20, "pm10":corrs_pm10_20, "pm25":corrs_pm25_20, "temp":corrs_temp_20, "humi":corrs_humi_20, "rain":corrs_rain_20}

# %%
corrs_CONTENT_30 = []
corrs_pm10_30 = []
corrs_pm25_30 = []
corrs_temp_30 = []
corrs_humi_30 = []
corrs_rain_30 = []

for c in list(total_30.columns)[:-6] :
    corrs_CONTENT_30.append(spearmanr(total_30[["CONTENT"]], total_30[[c]])[0])
    corrs_pm10_30.append(spearmanr(total_30[["pm10"]], total_30[[c]])[0])
    corrs_pm25_30.append(spearmanr(total_30[["pm25"]], total_30[[c]])[0])
    corrs_temp_30.append(spearmanr(total_30[["temp"]], total_30[[c]])[0])
    corrs_humi_30.append(spearmanr(total_30[["humi"]], total_30[[c]])[0])
    corrs_rain_30.append(spearmanr(total_30[["rain"]], total_30[[c]])[0])
    
corrs_dict_30 = {"CONTENT":corrs_CONTENT_30, "pm10":corrs_pm10_30, "pm25":corrs_pm25_30, "temp":corrs_temp_30, "humi":corrs_humi_30, "rain":corrs_rain_30}

# %%
corrs_CONTENT_40 = []
corrs_pm10_40 = []
corrs_pm25_40 = []
corrs_temp_40 = []
corrs_humi_40 = []
corrs_rain_40 = []

for c in list(total_40.columns)[:-6] :
    corrs_CONTENT_40.append(spearmanr(total_40[["CONTENT"]], total_40[[c]])[0])
    corrs_pm10_40.append(spearmanr(total_40[["pm10"]], total_40[[c]])[0])
    corrs_pm25_40.append(spearmanr(total_40[["pm25"]], total_40[[c]])[0])
    corrs_temp_40.append(spearmanr(total_40[["temp"]], total_40[[c]])[0])
    corrs_humi_40.append(spearmanr(total_40[["humi"]], total_40[[c]])[0])
    corrs_rain_40.append(spearmanr(total_40[["rain"]], total_40[[c]])[0])
    
corrs_dict_40 = {"CONTENT":corrs_CONTENT_40, "pm10":corrs_pm10_40, "pm25":corrs_pm25_40, "temp":corrs_temp_40, "humi":corrs_humi_40, "rain":corrs_rain_40}

# %%
corrs_CONTENT_50 = []
corrs_pm10_50 = []
corrs_pm25_50 = []
corrs_temp_50 = []
corrs_humi_50 = []
corrs_rain_50 = []

for c in list(total_50.columns)[:-6] :
    corrs_CONTENT_50.append(spearmanr(total_50[["CONTENT"]], total_50[[c]])[0])
    corrs_pm10_50.append(spearmanr(total_50[["pm10"]], total_50[[c]])[0])
    corrs_pm25_50.append(spearmanr(total_50[["pm25"]], total_50[[c]])[0])
    corrs_temp_50.append(spearmanr(total_50[["temp"]], total_50[[c]])[0])
    corrs_humi_50.append(spearmanr(total_50[["humi"]], total_50[[c]])[0])
    corrs_rain_50.append(spearmanr(total_50[["rain"]], total_50[[c]])[0])
    
corrs_dict_50 = {"CONTENT":corrs_CONTENT_50, "pm10":corrs_pm10_50, "pm25":corrs_pm25_50, "temp":corrs_temp_50, "humi":corrs_humi_50, "rain":corrs_rain_50}

# %%
sp_df_20 = pd.DataFrame(corrs_dict_20, columns = total_20.columns[-6:], index = total_20.columns[:-6])
sp_df_30 = pd.DataFrame(corrs_dict_30, columns = total_30.columns[-6:], index = total_30.columns[:-6])
sp_df_40 = pd.DataFrame(corrs_dict_40, columns = total_40.columns[-6:], index = total_40.columns[:-6])
sp_df_50 = pd.DataFrame(corrs_dict_50, columns = total_50.columns[-6:], index = total_50.columns[:-6])

# %%
sp_df_20.loc[:, 'CONTENT'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_news_20.png", dpi = 300)

# %%
sp_df_20.loc[:, 'pm10'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_pm10_20.png", dpi = 300)

# %%
sp_df_20.loc[:, 'pm25'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_pm25_20.png", dpi = 300)

# %%
sp_df_30.loc[:, 'CONTENT'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_news_30.png", dpi = 300)

# %%
sp_df_30.loc[:, 'pm10'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_pm10_30.png", dpi = 300)

# %%
sp_df_30.loc[:, 'pm25'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_pm25_30.png", dpi = 300)

# %%
sp_df_40.loc[:, 'CONTENT'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_news_40.png", dpi = 300)

# %%
sp_df_40.loc[:, 'pm10'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_pm10_40.png", dpi = 300)

# %%
sp_df_40.loc[:, 'pm25'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_pm25_40.png", dpi = 300)

# %%
sp_df_50.loc[:, 'CONTENT'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_news_50.png", dpi = 300)

# %%
sp_df_50.loc[:, 'pm10'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_pm10_50.png", dpi = 300)

# %%
sp_df_50.loc[:, 'pm25'].sort_values(ascending = False).plot(kind = 'barh', figsize = (10, 5), xlim = [-1,1], color = 'grey')
plt.axvline(0, color = 'k')
plt.savefig("/root/Big_Contest/EDA/JONGRO/img/spearman_pm25_50.png", dpi = 300)

# %%
sp_df_20.CONTENT[abs(sp_df_20.CONTENT) >= 0.45].sort_values()
# Out:
# age20accum           -0.597226
# age20cloth           -0.557186
# age20leisure goods   -0.534460
# age20stuff           -0.480500
# Name: CONTENT, dtype: float64

# %%
sp_df_20.pm10[abs(sp_df_20.pm10) >= 0.3].sort_values()
# Out:
# LCLS_30_P         -0.446410
# age20car repair   -0.404956
# Name: pm10, dtype: float64

# %%
sp_df_20.pm25[abs(sp_df_20.pm25) >= 0.3].sort_values()
# Out:
# age20car repair   -0.357196
# LCLS_30_P         -0.330576
# Name: pm25, dtype: float64

# %%
sp_df_30.CONTENT[abs(sp_df_30.CONTENT) >= 0.45].sort_values()
# Out:
# age30accum     -0.531411
# age30book      -0.470195
# age30culture   -0.462508
# age30stuff     -0.462030
# age30cloth     -0.460870
# age30medical    0.491963
# Name: CONTENT, dtype: float64

# %%
sp_df_30.pm10[abs(sp_df_30.pm10) >= 0.3].sort_values()
# Out:
# LCLS_30_P           -0.446410
# age30car repair     -0.357538
# age30leisure busi    0.393652
# Name: pm10, dtype: float64

# %%
sp_df_30.pm25[abs(sp_df_30.pm25) >= 0.3].sort_values()
# Out:
# age30car repair     -0.335211
# LCLS_30_P           -0.330576
# age30leisure busi    0.349007
# Name: pm25, dtype: float64

# %%
sp_df_40.CONTENT[abs(sp_df_40.CONTENT) >= 0.45].sort_values()
# Out:
# age40culture   -0.466611
# age40medical    0.477342
# Name: CONTENT, dtype: float64

# %%
sp_df_40.pm10[abs(sp_df_40.pm10) >= 0.3].sort_values()
# Out:
# LCLS_30_P   -0.44641
# Name: pm10, dtype: float64

# %%
sp_df_40.pm25[abs(sp_df_40.pm25) >= 0.3].sort_values()
# Out:
# LCLS_30_P   -0.330576
# Name: pm25, dtype: float64

# %%
sp_df_50.CONTENT[abs(sp_df_50.CONTENT) >= 0.45].sort_values()
# Out:
# age50medical    0.520777
# Name: CONTENT, dtype: float64

# %%
sp_df_50.pm10[abs(sp_df_50.pm10) >= 0.3].sort_values()
# Out:
# LCLS_30_P           -0.446410
# age50food            0.301478
# age50leisure busi    0.395397
# Name: pm10, dtype: float64

# %%
sp_df_50.pm25[abs(sp_df_50.pm25) >= 0.3].sort_values()
# Out:
# LCLS_30_P           -0.330576
# age50leisure busi    0.371616
# Name: pm25, dtype: float64

# %%
sns.regplot(x="CONTENT", y="age20accum", data=total_20, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
plt.yticks([200, 400, 600, 800, 1000, 1200])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim((10, 1000))
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/JONGRO/age20accum_CONTENT",dpi=300)

# %%
sns.regplot(x="CONTENT", y="age20cloth", data=total_20, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
# plt.yticks([0, 200, 400, 600])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/JONGRO/age20cloth_CONTENT",dpi=300)

# %%
sns.regplot(x="CONTENT", y="age20leisure goods", data=total_20, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
# plt.yticks([500, 1000, 1500, 2000])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/JONGRO/age20leisuregoods_CONTENT",dpi=300)

# %%
sns.regplot(x="CONTENT", y="age30accum", data=total_30, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
# plt.yticks([12500, 15000, 17500, 20000, 22500])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
# plt.ylim([12500, 22500])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/JONGRO/age30accum_CONTENT",dpi=300)

# %%
sns.regplot(x="CONTENT", y="age40medical", data=total_40, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
# plt.yticks([20000, 25000, 30000, 35000, 40000])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
# plt.ylim([20000, 40000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/JONGRO/age40medical_CONTENT",dpi=300)

# %%
sns.regplot(x="CONTENT", y="age40culture", data=total_40, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
# plt.yticks([10000, 15000, 20000, 25000, 30000])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
# plt.ylim([15000, 30000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/JONGRO/age40culture_CONTENT",dpi=300)

# %%
sns.regplot(x="CONTENT", y="age40leisure busi", data=total_40, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
plt.yticks([500, 1000, 1500, 2000])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/NOWON/age40leisure busi_CONTENT",dpi=300)

# %%
sns.regplot(x="CONTENT", y="age40culture", data=total_40, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
# plt.yticks([1500, 2000, 2500, 3000])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/JONGRO/age40culture_CONTENT",dpi=300)

# %%
sns.regplot(x="CONTENT", y="age50medical", data=total_50, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
plt.yticks(np.arange(1000, 11000, 3000))
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/JONGRO/age50medical_CONTENT",dpi=300)

# %%
print("Sunday : ", (total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index.day_name() == 'Sunday').sum()/(total_50.age50medical < 1500).sum())
print("Tuesday : ", (total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index.day_name() == 'Tuesday').sum()/(total_50.age50medical < 1500).sum())
print("Wednesday : ", (total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index.day_name() == 'Wednesday').sum()/(total_50.age50medical < 1500).sum())
print("Monday : ", (total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index.day_name() == 'Monday').sum()/(total_50.age50medical < 1500).sum())
# Out:
# Sunday :  0.8153846153846154
# Tuesday :  0.09230769230769231
# Wednesday :  0.06153846153846154
# Monday :  0.03076923076923077

# %%
0.8153846153846154 + 0.09230769230769231 + 0.06153846153846154 + 0.03076923076923077
# Out:
# 1.0

# %%
print(np.where(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index.day_name() == 'Tuesday')[0])

print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[8])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[30])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[34])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[46])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[48])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[55])
# Out:
# [ 8 30 34 46 48 55]
# 2018-05-22 00:00:00
# 2018-09-25 00:00:00
# 2018-10-09 00:00:00
# 2018-12-25 00:00:00
# 2019-01-01 00:00:00
# 2019-02-05 00:00:00

# %%
print(np.where(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index.day_name() == 'Wednesday')[0])

print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[11])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[22])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[32])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[56])
# Out:
# [11 22 32 56]
# 2018-06-06 00:00:00
# 2018-08-15 00:00:00
# 2018-10-03 00:00:00
# 2019-02-06 00:00:00

# %%
print(np.where(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index.day_name() == 'Monday')[0])

print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[29])
print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[54])
# Out:
# [29 54]
# 2018-09-24 00:00:00
# 2019-02-04 00:00:00

# %%
print(np.where(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index.day_name() == 'Friday')[0])

print(total_50.iloc[np.where(total_50.age50medical < 1500)[0]].index[60])
# Out:
# [60]
# 2019-03-01 00:00:00

# %%
### 2018년 5월 22일 = 부처님 오신날
### 2018년 6월 6일 = 현충일
### 2018년 8월 15일 = 광복절
### 2018년 9월 24일 = 추석
### 2018년 9월 25일 = 추석
### 2018년 10월 3일 = 개천절
### 2018년 10월 9일 = 한글날
### 2018년 12월 25일 = 크리스마스
### 2019년 1월 1일 = 신년
### 2019년 2월 4일 = 설날
### 2019년 2월 5일 = 설날
### 2019년 2월 6일 = 설날
### 2019년 3월 1일 = 삼일절

# %%
medical_BD_50 = total_50.iloc[np.where(total_50.age50medical > 1500)[0]]

# %%
medical_BD_50.head()
# Out:
#             age50leisure busi  age50culture  age50fuel  age50circul  \
# 2018-04-02              643.0         210.0     2265.0      26613.0
# 2018-04-03              771.0         173.0     2106.0      26966.0
# 2018-04-04              751.0         225.0     2103.0      28748.0
# 2018-04-05              719.0         183.0     2023.0      24812.0
# 2018-04-06              775.0         226.0     2434.0      25546.0
#
#             age50cloth  age50stuff  age50book  age50medical  \
# 2018-04-02       513.0       140.0      687.0        8666.0
# 2018-04-03       546.0       107.0      669.0        7405.0
# 2018-04-04       396.0       107.0      659.0        6935.0
# 2018-04-05       243.0        76.0      549.0        6381.0
# 2018-04-06       351.0        66.0      713.0        7160.0
#
#             age50public health  age50food  ...  LCLS_50_P  LCLS_60_P  \
# 2018-04-02              1307.0    13421.0  ...     732014      85751
# 2018-04-03              1381.0    13933.0  ...     694118     109181
# 2018-04-04              1335.0    14271.0  ...     914432     106260
# 2018-04-05              1278.0    13619.0  ...    1099378     120809
# 2018-04-06              1277.0    14134.0  ...     936436      88341
#
#             LCLS_70_P  LCLS_80_P       temp       humi       pm10       pm25  \
# 2018-04-02     189721     159773  19.631111  57.827083  71.924306  29.909028
# 2018-04-03     146743      83460  19.192500  61.674306  72.979861  24.331944
# 2018-04-04     133827      85526  14.075417  60.129861  18.221528  10.952778
# 2018-04-05     149481      89173   8.620000  77.163194   8.854861   3.891667
# 2018-04-06     121884      78087   7.356944  62.684028  93.359722  31.615278
#
#             rain  CONTENT
# 2018-04-02   0.0      888
# 2018-04-03   0.1      856
# 2018-04-04  18.5      893
# 2018-04-05  10.5      864
# 2018-04-06   6.5      900
#
# [5 rows x 26 columns]

# %%
sns.regplot(x="CONTENT", y="age50medical", data=medical_BD_50, line_kws={'color': 'red'}, color = 'k', scatter_kws={'s':10})
plt.xlabel("news")
plt.yticks([4000, 6000, 8000, 10000])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
plt.ylim([4000, 10000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/NOWON/age50medical(BD)_CONTENT",dpi=300)

# %%
plt.scatter(x = medical_BD_50[["CONTENT"]], y = medical_BD_50[["age50medical"]], c = 'k', s = 10, alpha = 0.8)
plt.xlabel("news")
plt.ylabel("age50medical(BD)")
plt.yticks([4000, 6000, 8000, 10000])
plt.xticks([10, 200, 400, 600, 800, 1000], (0, 200, 400, 600, 800, 1000))
plt.xlim([10, 1000])
plt.ylim([4000, 10000])
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits=(0,0))
plt.savefig("/root/Big_Contest/EDA/NOWON/age50medical(BD)_CONTENT",dpi=300)
