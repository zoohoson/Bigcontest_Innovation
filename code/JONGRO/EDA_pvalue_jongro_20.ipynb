# %% [markdown]
# # Multi Linear Regression을 이용하여 p-value 계산하기
# ## p-value : 귀무가설을 가정하였을 때 표본 이상으로 극단적인 결과를 얻을 확률
# ## 귀무가설 : Multi Linear Regression을 사용하여 회귀모델을 설계할 때 각 feature의 coefficient가 0이 됨
# - 따라서 p-value는 극단적인 결과를 얻을 확률이 적어야 안정적인 해당 feature가 안정적이라고 할 수 있다.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import sklearn
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline

import scipy.stats as stats
import urllib
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.anova import anova_lm
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import train_test_split

# %%
# 나이대 별로 약 20개 이상의 feature에 대한 p-value를 확인해야하므로 나이대 별로 서로 다른 파일에 저장
df_20 = pd.read_csv('../data/innovation/Merge_data/df_age20_jongro.csv')

# %%
df_20.head()
# Out:
#    age20accum  age20leisure goods  age20leisure busi  age20culture  \
# 0       685.0               318.0             3730.0        1977.0
# 1       212.0               188.0             2626.0         596.0
# 2       257.0               192.0             2831.0         782.0
# 3       205.0               202.0             2716.0         772.0
# 4       273.0               184.0             2898.0        1001.0
#
#    age20furniture  age20electronic  age20kitchen  age20fuel  age20optic  \
# 0             0.0              0.0           0.0       59.0        99.0
# 1             0.0              0.0           0.0       55.0        91.0
# 2            12.0              0.0           0.0       64.0       113.0
# 3             8.0              0.0          17.0        0.0       106.0
# 4             0.0              0.0          21.0       47.0        60.0
#
#    age20Appliances  ...  LCLS_50_P  LCLS_60_P  LCLS_70_P  LCLS_80_P  \
# 0             17.0  ...      68124      10029      15065       4995
# 1              0.0  ...      66428       9316      15306       3638
# 2             51.0  ...      66698       7793      13618       2648
# 3             56.0  ...      83667       9649      19985       3078
# 4             21.0  ...     108727       9057      13849       3796
#
#         pm10       pm25       humi       temp  CONTENT  rain
# 0  84.070139  43.877083  61.370139  16.692569      515   0.0
# 1  72.274306  30.051389  58.825694  19.561181      888   0.0
# 2  66.162500  19.478472  63.531944  19.282292      856   0.1
# 3  18.021097  10.726442  62.014583  14.202361      893  18.5
# 4  11.831711   8.579972  79.125000   8.963056      864  10.5
#
# [5 rows x 38 columns]

# %%
df_20.columns
# Out:
# Index(['age20accum', 'age20leisure goods', 'age20leisure busi', 'age20culture',
#        'age20furniture', 'age20electronic', 'age20kitchen', 'age20fuel',
#        'age20optic', 'age20Appliances', 'age20circul', 'age20cloth',
#        'age20textile', 'age20stuff', 'age20book', 'age20affair',
#        'age20car sell', 'age20car repair', 'age20medical',
#        'age20public health', 'age20food', 'age20grocery',
#        'age20repair survice', 'age20', 'LCLS_10_P', 'LCLS_20_P', 'LCLS_30_P',
#        'LCLS_40_P', 'LCLS_50_P', 'LCLS_60_P', 'LCLS_70_P', 'LCLS_80_P', 'pm10',
#        'pm25', 'humi', 'temp', 'CONTENT', 'rain'],
#       dtype='object')

# %%
df_20.columns = ['age20accum', 'age20leisure_goods', 'age20leisure_busi', 'age20culture',
       'age20furniture', 'age20electronic', 'age20kitchen', 'age20fuel',
       'age20optic', 'age20Appliances', 'age20circul', 'age20cloth',
       'age20textile', 'age20stuff', 'age20book', 'age20affair',
       'age20car_sell', 'age20car_repair', 'age20medical',
       'age20public_health', 'age20food', 'age20grocery',
       'age20repair_survice', 'age20', 'LCLS_10_P', 'LCLS_20_P', 'LCLS_30_P',
       'LCLS_40_P', 'LCLS_50_P', 'LCLS_60_P', 'LCLS_70_P', 'LCLS_80_P', 'pm10',
       'pm25', 'humi', 'temp', 'CONTENT', 'rain']

# %%
def anova(col_name):
    formula = col_name + ' ~ pm10 + pm25 + temp + humi + CONTENT + rain + CONTENT:temp + CONTENT:rain + CONTENT:humi'
    lm = ols(formula, df_20).fit()
    return lm.summary()

# %% [markdown]
# ## 20대 숙박

# %%
print(anova("age20accum")) # CONTENT
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             age20accum   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     26.08
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           2.08e-34
# Time:                        23:04:26   Log-Likelihood:                -2397.8
# No. Observations:                 365   AIC:                             4816.
# Df Residuals:                     355   BIC:                             4855.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      569.5014     88.338      6.447      0.000     395.770     743.233
# pm10            -0.4858      0.825     -0.589      0.556      -2.108       1.137
# pm25             1.7036      1.122      1.519      0.130      -0.503       3.910
# temp             6.6062      2.332      2.833      0.005       2.020      11.193
# humi             1.5821      1.993      0.794      0.428      -2.337       5.501
# CONTENT         -0.0914      0.140     -0.651      0.515      -0.367       0.185
# rain            -1.7813      2.156     -0.826      0.409      -6.021       2.458
# CONTENT:temp    -0.0184      0.004     -4.177      0.000      -0.027      -0.010
# CONTENT:rain     0.0037      0.004      1.005      0.316      -0.004       0.011
# CONTENT:humi    -0.0043      0.003     -1.331      0.184      -0.011       0.002
# ==============================================================================
# Omnibus:                        8.352   Durbin-Watson:                   1.419
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                8.865
# Skew:                           0.288   Prob(JB):                       0.0119
# Kurtosis:                       3.502   Cond. No.                     2.97e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(anova('age20cloth')) # CONTENT
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             age20cloth   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.350
# Method:                 Least Squares   F-statistic:                     22.81
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           1.38e-30
# Time:                        23:04:26   Log-Likelihood:                -2643.6
# No. Observations:                 365   AIC:                             5307.
# Df Residuals:                     355   BIC:                             5346.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1590.2234    173.237      9.179      0.000    1249.523    1930.924
# pm10            -3.3834      1.618     -2.091      0.037      -6.566      -0.201
# pm25             5.2236      2.200      2.374      0.018       0.897       9.550
# temp             7.7626      4.574      1.697      0.091      -1.232      16.757
# humi            -1.5054      3.908     -0.385      0.700      -9.191       6.180
# CONTENT         -0.3726      0.275     -1.354      0.177      -0.914       0.169
# rain           -12.3294      4.228     -2.916      0.004     -20.644      -4.015
# CONTENT:temp    -0.0107      0.009     -1.235      0.218      -0.028       0.006
# CONTENT:rain     0.0109      0.007      1.515      0.131      -0.003       0.025
# CONTENT:humi    -0.0063      0.006     -0.990      0.323      -0.019       0.006
# ==============================================================================
# Omnibus:                       53.036   Durbin-Watson:                   1.281
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.035
# Skew:                           0.816   Prob(JB):                     3.13e-22
# Kurtosis:                       4.962   Cond. No.                     2.97e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(anova('age20leisure_goods')) # CONTENT
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     age20leisure_goods   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     21.13
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           1.51e-28
# Time:                        23:04:34   Log-Likelihood:                -2190.9
# No. Observations:                 365   AIC:                             4402.
# Df Residuals:                     355   BIC:                             4441.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      263.6827     50.113      5.262      0.000     165.127     362.239
# pm10            -0.2022      0.468     -0.432      0.666      -1.123       0.718
# pm25             1.0063      0.636      1.581      0.115      -0.245       2.258
# temp             5.5542      1.323      4.198      0.000       2.952       8.156
# humi             0.9937      1.130      0.879      0.380      -1.230       3.217
# CONTENT          0.0162      0.080      0.203      0.839      -0.140       0.173
# rain            -2.0477      1.223     -1.674      0.095      -4.453       0.357
# CONTENT:temp    -0.0096      0.003     -3.855      0.000      -0.015      -0.005
# CONTENT:rain     0.0026      0.002      1.264      0.207      -0.001       0.007
# CONTENT:humi    -0.0029      0.002     -1.581      0.115      -0.007       0.001
# ==============================================================================
# Omnibus:                       47.313   Durbin-Watson:                   1.532
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.485
# Skew:                           0.754   Prob(JB):                     4.51e-19
# Kurtosis:                       4.812   Cond. No.                     2.97e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(anova('age20stuff')) # CONTENT
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             age20stuff   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     16.85
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           3.86e-23
# Time:                        23:04:46   Log-Likelihood:                -2538.7
# No. Observations:                 365   AIC:                             5097.
# Df Residuals:                     355   BIC:                             5136.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      963.5266    129.959      7.414      0.000     707.940    1219.113
# pm10            -1.8920      1.214     -1.559      0.120      -4.279       0.495
# pm25             3.6133      1.650      2.189      0.029       0.368       6.859
# temp             3.0308      3.431      0.883      0.378      -3.717       9.778
# humi             0.8146      2.932      0.278      0.781      -4.951       6.580
# CONTENT         -0.2120      0.206     -1.027      0.305      -0.618       0.194
# rain            -7.3985      3.171     -2.333      0.020     -13.636      -1.161
# CONTENT:temp    -0.0127      0.006     -1.955      0.051      -0.025    7.35e-05
# CONTENT:rain     0.0072      0.005      1.336      0.182      -0.003       0.018
# CONTENT:humi    -0.0047      0.005     -0.982      0.327      -0.014       0.005
# ==============================================================================
# Omnibus:                       50.138   Durbin-Watson:                   1.400
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.327
# Skew:                           0.813   Prob(JB):                     2.96e-19
# Kurtosis:                       4.722   Cond. No.                     2.97e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(anova("LCLS_30_P")) # pm10
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              LCLS_30_P   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     192.8
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):          7.51e-131
# Time:                        23:05:05   Log-Likelihood:                -4266.4
# No. Observations:                 365   AIC:                             8553.
# Df Residuals:                     355   BIC:                             8592.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     4.049e+05   1.48e+04     27.404      0.000    3.76e+05    4.34e+05
# pm10          -431.6831    137.997     -3.128      0.002    -703.078    -160.288
# pm25           577.6202    187.624      3.079      0.002     208.626     946.614
# temp          6451.6779    390.057     16.540      0.000    5684.565    7218.791
# humi         -1560.2850    333.297     -4.681      0.000   -2215.770    -904.800
# CONTENT        -31.6596     23.468     -1.349      0.178     -77.813      14.494
# rain         -1475.9778    360.552     -4.094      0.000   -2185.065    -766.891
# CONTENT:temp    -0.5439      0.737     -0.738      0.461      -1.994       0.906
# CONTENT:rain     0.3534      0.612      0.578      0.564      -0.850       1.556
# CONTENT:humi     0.8145      0.543      1.500      0.135      -0.253       1.883
# ==============================================================================
# Omnibus:                        8.845   Durbin-Watson:                   1.284
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.768
# Skew:                          -0.358   Prob(JB):                       0.0125
# Kurtosis:                       3.250   Cond. No.                     2.97e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(anova("age20car_repair")) # pm10
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        age20car_repair   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.286
# Method:                 Least Squares   F-statistic:                     17.23
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           1.25e-23
# Time:                        23:05:20   Log-Likelihood:                -2409.8
# No. Observations:                 365   AIC:                             4840.
# Df Residuals:                     355   BIC:                             4879.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      896.8064     91.297      9.823      0.000     717.256    1076.356
# pm10            -1.2903      0.853     -1.513      0.131      -2.967       0.387
# pm25             0.9876      1.159      0.852      0.395      -1.293       3.268
# temp             8.4444      2.410      3.504      0.001       3.704      13.185
# humi            -3.5473      2.060     -1.722      0.086      -7.598       0.503
# CONTENT         -0.2030      0.145     -1.400      0.162      -0.488       0.082
# rain            -3.9979      2.228     -1.794      0.074      -8.380       0.384
# CONTENT:temp     0.0008      0.005      0.182      0.855      -0.008       0.010
# CONTENT:rain     0.0045      0.004      1.195      0.233      -0.003       0.012
# CONTENT:humi     0.0013      0.003      0.379      0.705      -0.005       0.008
# ==============================================================================
# Omnibus:                       52.964   Durbin-Watson:                   1.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.855
# Skew:                           0.807   Prob(JB):                     1.26e-22
# Kurtosis:                       5.007   Cond. No.                     2.97e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
